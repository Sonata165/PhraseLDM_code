# %%
# The latent looks so similar, how come the mse is so large

import torch
gt_latent = '/home/longshen/work/AccGen/AccGen/temp/bar_latent_debug/debug_first_sample_bar_latent_scaled.pt'
out_latent = '/home/longshen/work/AccGen/AccGen/temp/bar_latent_debug/model_out_200.pt'
gt = torch.load(gt_latent).cpu()
out = torch.load(out_latent).cpu()
mse = torch.nn.MSELoss()(gt, out)
print("MSE:", mse.item())
# Out:
# MSE: 0.007466266397386789
